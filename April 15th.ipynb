# %%
Return 
return is used to: Send a value back from a function. or
                   End the function execution.
*** run`s once

# %%
def add(a,b):
    return a+ b
result = add(10,12)
print(result)
# Out:
# 22

# %%
def multiply(a,b,c):
    return(a*b*c)

result = multiply(12,3,16)
print(result)
# Out:
# 576

# %%
def calc(a,b):
    return a+b, a*b

sum_val, mult_val = calc(3,4)
print (sum_val, mult_val)
# Out:
# 7 12

# %%
def check_even(n):
    if n % 2 == 0:
        return "Even"
    return "Odd"
result = check_even(16)
print (result)
# Out:
# Even

# %%
def square(a):
    return(a*a)
result = square(12)
print(result)
# Out:
# 144

# %%
def max_num(a,b,c):
    return max(a,b,c)


result = max_num( 4,7,5)
print(result)
# Out:
# 7

# %%
def max_num(a,b):
    return a if a>b else b

result= max_num(4,9)
print(result)
# Out:
# 9

# %%
def fact(n):
    return(n**n)
result = fact(3)
print (result)
# Out:
# 27

# %%
def vowels_count(s):
    count = 0 
    vowels = "aeiou"
    
    for char in s.lower():
        if char in vowels:
            count += 1
    return (count)
               
result= vowels_count ("explain")
print(result)
# Out:
# 3

# %%
palindrome- A string is a palindrome if it reads the same forward and backward.

Examples:
"madam" → ✅ Palindrome
"racecar" → ✅ Palindrome
"hello" → ❌ Not palindrome
